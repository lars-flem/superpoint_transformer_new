# %% [markdown]
# # Binary model trained on Norwegian Data

# %% [markdown]
# ## Model

# %%
import os, sys
from pathlib import Path

# Finn repo-root ved å gå oppover til vi finner src/train.py
here = Path().cwd().resolve()
PROJECT_ROOT = None
for p in [here, *here.parents]:
    if (p / "src" / "train.py").exists():
        PROJECT_ROOT = p
        break

assert PROJECT_ROOT is not None, f"Fant ikke src/train.py fra {here}"

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT))

print("Repo root:", PROJECT_ROOT)
print("Train path:", PROJECT_ROOT / "src" / "train.py")
# Out:
# Repo root: /cluster/home/jakobep/superpoint_transformer_new
# Train path: /cluster/home/jakobep/superpoint_transformer_new/src/train.py

# %%
import importlib
m = importlib.import_module("src.datamodules.norway_binary")
print("ok import", m)
print("has class", hasattr(m, "NorwayBinaryDataModule"))
# Out:
# ok import <module 'src.datamodules.norway_binary' from '/cluster/home/jakobep/superpoint_transformer_new/src/datamodules/norway_binary.py'>
# has class True

# %%
### Fungerende kommando
"""
source ~/.bashrc && conda activate spta100 && cd /cluster/home/jakobep/superpoint_transformer && python src/train.py \
    experiment=semantic/dales_11g \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing \
    trainer.max_epochs=20 \
    trainer.check_val_every_n_epoch=5 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=5 \
    callbacks.model_checkpoint.monitor=null \
    test=True \
    logger=csv 2>&1 | tee /tmp/train_output.log
"""



# Med Optuna hyperparameter tuning
"""
source ~/.bashrc && conda activate spta100 && cd /cluster/home/jakobep/superpoint_transformer && python src/train.py -m \
    hparams_search=norway_binary_optuna \
    experiment=semantic/dales_11g \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing \
    trainer.max_epochs=20 \
    trainer.check_val_every_n_epoch=5 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=5 \
    callbacks.model_checkpoint.monitor=null \
    test=False \
    logger=csv 2>&1 | tee /tmp/optuna_search.log
"""

#Enkel test
"""
source ~/.bashrc && conda activate sptez && cd /cluster/home/jakobep/superpoint_transformer_new && python src/train.py \
    experiment=semantic/dales_11g \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing \
    trainer.max_epochs=50 \
    trainer.check_val_every_n_epoch=5 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=5 \
    callbacks.model_checkpoint.monitor=null \
    test=True \
    logger=csv 2>&1 | tee /tmp/train_output.log
"""


#Slette gamle processed data
""" 
rm -rf /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/
"""

#Slette gamle processed data
""" 
rm -rf /cluster/home/jakobep/datasets/bergen2023_binary_testing/norwaybinaryals/processed/
"""

# %%
"""
source ~/.bashrc && conda activate sptez && cd /cluster/home/jakobep/superpoint_transformer_new && python src/train.py \
    experiment=semantic/dales \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing \
    trainer.check_val_every_n_epoch=5 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=5 \
    callbacks.model_checkpoint.monitor=null \
    test=True \
    logger=csv 2>&1 | tee /tmp/train_output.log
"""

# %%
"""
source ~/.bashrc && conda activate sptez && cd /cluster/home/jakobep/superpoint_transformer_new && python src/train.py \
    experiment=semantic/dales \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/bergen2023_binary_testing \
    trainer.check_val_every_n_epoch=5 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=5 \
    callbacks.model_checkpoint.monitor=null \
    test=True \
    logger=csv 2>&1 | tee /tmp/train_output.log
"""

# %%
import subprocess, sys, os
from pathlib import Path

os.environ["HYDRA_FULL_ERROR"] = "1"
os.environ["WANDB_MODE"] = "disabled"
os.environ["WANDB_SILENT"] = "true"

DATA_ROOT = Path("/cluster/home/jakobep/datasets/norway_binary_testing").resolve()
TRAIN_PY = (Path().cwd() / "src" / "train.py").resolve()

cmd = [
    sys.executable, str(TRAIN_PY),
    "experiment=semantic/dales_11g",
    "datamodule=semantic/norway_binary",
    f"paths.data_dir={DATA_ROOT}",
    "trainer.max_epochs=1",
    "+trainer.limit_train_batches=10",
    "+trainer.limit_val_batches=2",
    "+trainer.num_sanity_val_steps=0",
    "+trainer.enable_progress_bar=true",
    "logger=csv",
]

print(" ".join(cmd))

p = subprocess.run(cmd, cwd=str(Path().cwd()), text=True, capture_output=True)
print("RETURN CODE:", p.returncode)
print("\n===== STDOUT =====\n", p.stdout[-8000:])  # viser siste del
print("\n===== STDERR =====\n", p.stderr[-8000:])  # ofte der feilen ligger

# Hvis du vil stoppe notebooken når den feiler:
p.check_returncode()
# Out:
# /cluster/home/jakobep/.conda/envs/sptez/bin/python /cluster/home/jakobep/superpoint_transformer_new/notebooks/src/train.py experiment=semantic/dales_11g datamodule=semantic/norway_binary paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing trainer.max_epochs=1 +trainer.limit_train_batches=10 +trainer.limit_val_batches=2 +trainer.num_sanity_val_steps=0 +trainer.enable_progress_bar=true logger=csv
# RETURN CODE: 2
#
# ===== STDOUT =====
#
#
# ===== STDERR =====
#  /cluster/home/jakobep/.conda/envs/sptez/bin/python: can't open file '/cluster/home/jakobep/superpoint_transformer_new/notebooks/src/train.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 32
#      29 print("\n===== STDERR =====\n", p.stderr[-8000:])  # ofte der feilen ligger
#      31 # Hvis du vil stoppe notebooken når den feiler:
# ---> 32 p.check_returncode()
#
# File ~/.conda/envs/sptez/lib/python3.8/subprocess.py:448, in CompletedProcess.check_returncode(self)
#     446 """Raise CalledProcessError if the exit code is non-zero."""
#     447 if self.returncode:
# --> 448     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     449                              self.stderr)
#
# CalledProcessError: Command '['/cluster/home/jakobep/.conda/envs/sptez/bin/python', '/cluster/home/jakobep/superpoint_transformer_new/notebooks/src/train.py', 'experiment=semantic/dales_11g', 'datamodule=semantic/norway_binary', 'paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing', 'trainer.max_epochs=1', '+trainer.limit_train_batches=10', '+trainer.limit_val_batches=2', '+trainer.num_sanity_val_steps=0', '+trainer.enable_progress_bar=true', 'logger=csv']' returned non-zero exit status 2.

# %%
"""
python src/train.py \
    experiment=semantic/dales_11g \
    datamodule=semantic/norway_binary \
    paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing \
    trainer.max_epochs=1 \
    +trainer.limit_train_batches=10 \
    +trainer.limit_val_batches=2 \
    logger=csv
"""

# %%
import os
os.environ["HYDRA_FULL_ERROR"] = "1"
os.environ["WANDB_MODE"] = "disabled"
os.environ["WANDB_SILENT"] = "true"

DATA_ROOT = "/cluster/home/jakobep/datasets/norway_binary_testing"

# Kjør trening - UTEN limit_batches for å få checkpoint lagret
# !python src/train.py \
    experiment=semantic/dales_11g \
    datamodule=semantic/norway_binary \
    paths.data_dir={DATA_ROOT} \
    trainer.max_epochs=1 \
    callbacks.model_checkpoint.save_last=True \
    callbacks.model_checkpoint.every_n_epochs=1 \
    callbacks.model_checkpoint.monitor=null \
    logger=csv
# Out:
# [2026-02-16 13:43:02,294][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2026-02-16 13:43:02,305][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── datamodule
# │   └── nano: false
# │       partition_hf:
# │       - linearity
# │       - planarity
# │       - scattering
# │       - elevation
# │       point_hf:
# │       - linearity
# │       - planarity
# │       - scattering
# │       - verticality
# │       - elevation
# │       post_cnn_point_hf: []
# │       segment_base_hf: []
# │       segment_mean_hf: []
# │       segment_std_hf: []
# │       edge_hf:
# │       - mean_off
# │       - std_off
# │       - mean_dist
# │       v_edge_hf: []
# │       h_edge_hf_need_normal: false
# │       v_edge_hf_need_normal: false
# │       edge_hf_need_log_length: false
# │       edge_hf_need_log_surface: false
# │       edge_hf_need_log_volume: false
# │       edge_hf_need_log_size: false
# │       extra_point_hf: []
# │       extra_segment_hf: []
# │       segment_hf: []
# │       all_point_hf:
# │       - verticality
# │       - planarity
# │       - elevation
# │       - scattering
# │       - linearity
# │       point_hf_preprocess:
# │       - verticality
# │       - planarity
# │       - elevation
# │       - scattering
# │       - linearity
# │       segment_base_hf_preprocess: []
# │       segment_mean_hf_preprocess: []
# │       segment_std_hf_preprocess: []
# │       num_hf_partition: 4
# │       num_hf_point: 5
# │       num_hf_segment: 0
# │       num_hf_edge: 7
# │       num_hf_v_edge: 0
# │       obj_key:
# │       - obj
# │       point_hf_overwrite: true
# │       point_full_res_key:
# │       - sub
# │       point_save_keys: null
# │       point_no_save_keys:
# │       - edge_index
# │       - edge_attr
# │       - neighbor_index
# │       - neighbor_distance
# │       - node_size
# │       - grid_size
# │       - coords
# │       segment_save_keys: null
# │       point_basic_load_keys:
# │       - pos
# │       - pos_offset
# │       - 'y'
# │       - obj
# │       - super_index
# │       segment_basic_load_keys:
# │       - pos
# │       - 'y'
# │       - super_index
# │       - sub
# │       - edge_index
# │       - edge_attr
# │       point_load_keys:
# │       - verticality
# │       - pos_offset
# │       - planarity
# │       - super_index
# │       - obj
# │       - 'y'
# │       - elevation
# │       - scattering
# │       - pos
# │       - linearity
# │       segment_load_keys:
# │       - sub
# │       - edge_attr
# │       - super_index
# │       - 'y'
# │       - edge_index
# │       - pos
# │       quantize_coords: false
# │       feat_size:
# │         pos: 3
# │         pos_room: 3
# │         rgb: 3
# │         hsv: 3
# │         lab: 3
# │         density: 1
# │         linearity: 1
# │         planarity: 1
# │         scattering: 1
# │         verticality: 1
# │         normal: 3
# │         length: 1
# │         surface: 1
# │         volume: 1
# │         curvature: 1
# │         elevation: 1
# │         size: 1
# │         intensity: 1
# │         log_pos: 3
# │         log_pos_room: 3
# │         log_rgb: 3
# │         log_hsv: 3
# │         log_lab: 3
# │         log_density: 1
# │         log_linearity: 1
# │         log_planarity: 1
# │         log_scattering: 1
# │         log_verticality: 1
# │         log_normal: 3
# │         log_length: 1
# │         log_surface: 1
# │         log_volume: 1
# │         log_curvature: 1
# │         log_elevation: 1
# │         log_size: 1
# │         mean_pos: 3
# │         mean_pos_room: 3
# │         mean_rgb: 3
# │         mean_hsv: 3
# │         mean_lab: 3
# │         mean_density: 1
# │         mean_linearity: 1
# │         mean_planarity: 1
# │         mean_scattering: 1
# │         mean_verticality: 1
# │         mean_normal: 3
# │         mean_length: 1
# │         mean_surface: 1
# │         mean_volume: 1
# │         mean_curvature: 1
# │         mean_elevation: 1
# │         mean_size: 1
# │         mean_intensity: 1
# │         std_pos: 3
# │         std_pos_room: 3
# │         std_rgb: 3
# │         std_hsv: 3
# │         std_lab: 3
# │         std_density: 1
# │         std_linearity: 1
# │         std_planarity: 1
# │         std_scattering: 1
# │         std_verticality: 1
# │         std_normal: 3
# │         std_length: 1
# │         std_surface: 1
# │         std_volume: 1
# │         std_curvature: 1
# │         std_elevation: 1
# │         std_size: 1
# │         std_intensity: 1
# │         mean_off: 3
# │         std_off: 3
# │         mean_dist: 1
# │         angle_source: 1
# │         angle_target: 1
# │         centroid_dir: 3
# │         centroid_dist: 1
# │         normal_angle: 1
# │       _target_: src.datamodules.norway_binary.NorwayBinaryDataModule
# │       data_dir: /cluster/home/jakobep/datasets/norway_binary_testing
# │       num_classes: 2
# │       stuff_classes:
# │       - 0
# │       - 1
# │       instance: false
# │       instance_k_max: 30
# │       instance_radius: 0.1
# │       min_instance_size: 100
# │       mini: false
# │       save_y_to_csr: true
# │       save_pos_dtype: float32
# │       save_fp_dtype: float16
# │       load_non_fp_to_long: false
# │       in_memory: false
# │       lite_preprocessing: true
# │       prepare_only_test: false
# │       load_full_res_idx: false
# │       max_num_nodes: 50000
# │       max_num_edges: 1000000
# │       tta_runs: null
# │       tta_val: false
# │       submit: false
# │       dataloader:
# │         batch_size: 4
# │         num_workers: 4
# │         pin_memory: true
# │         persistent_workers: true
# │       non_blocking: true
# │       pre_transform:
# │       - transform: DataTo
# │         params:
# │           device: cuda
# │       - transform: SaveNodeIndex
# │         params:
# │           key: sub
# │       - transform: GridSampling3D
# │         params:
# │           size: 0.2
# │           hist_key: 'y'
# │           hist_size: 3
# │           inplace: true
# │           chunk_size: 10000000
# │       - transform: KNN
# │         params:
# │           k: 25
# │           r_max: 10
# │           verbose: false
# │       - transform: PointFeatures
# │         params:
# │           keys:
# │           - verticality
# │           - planarity
# │           - elevation
# │           - scattering
# │           - linearity
# │           k_min: 1
# │           k_step: -1
# │           k_min_search: 10
# │           overwrite: true
# │       - transform: DataTo
# │         params:
# │           device: cpu
# │       - transform: GroundElevation
# │         params:
# │           model: ransac
# │           z_threshold: 5
# │           xy_grid: 1
# │           scale: 20
# │       - transform: DataTo
# │         params:
# │           device: cuda
# │       - transform: AdjacencyGraph
# │         params:
# │           k: 10
# │           w: 1
# │       - transform: ConnectIsolated
# │         params:
# │           k: 1
# │       - transform: AddKeysTo
# │         params:
# │           keys:
# │           - linearity
# │           - planarity
# │           - scattering
# │           - elevation
# │           to: x
# │           delete_after: false
# │       - transform: CutPursuitPartition
# │         params:
# │           regularization:
# │           - 0.1
# │           - 0.2
# │           - 0.3
# │           spatial_weight:
# │           - 0.1
# │           - 0.01
# │           - 0.001
# │           k_adjacency: 10
# │           cutoff:
# │           - 10
# │           - 30
# │           - 100
# │           iterations: 15
# │           edge_reduce: mean
# │           parallel: true
# │           verbose: false
# │       - transform: NAGRemoveKeys
# │         params:
# │           level: all
# │           keys: x
# │       - transform: SegmentFeatures
# │         params:
# │           n_min: 32
# │           n_max: 128
# │           keys: []
# │           mean_keys: []
# │           std_keys: []
# │           strict: false
# │       - transform: RadiusHorizontalGraph
# │         params:
# │           k_min: 1
# │           k_max: 30
# │           gap:
# │           - 5
# │           - 30
# │           - 30
# │           se_ratio: 0.3
# │           se_min: 50
# │           cycles: 3
# │           margin: 0.5
# │           chunk_size:
# │           - 1000000.0
# │           - 100000.0
# │           - 100000.0
# │           halfspace_filter: true
# │           bbox_filter: true
# │           target_pc_flip: true
# │           source_pc_sort: false
# │           keys:
# │           - mean_off
# │           - std_off
# │           - mean_dist
# │       - transform: NAGTo
# │         params:
# │           device: cpu
# │       train_transform: null
# │       val_transform: null
# │       test_transform: null
# │       on_device_train_transform:
# │       - transform: NAGCast
# │       - transform: NodeSize
# │         params:
# │           low: 0
# │       - transform: SampleSubNodes
# │         params:
# │           low: 0
# │           high: 1
# │           n_min: 32
# │           n_max: 128
# │       - transform: SampleRadiusSubgraphs
# │         params:
# │           r: 50
# │           k: 2
# │           k_max: 10000
# │           i_level: 1
# │           by_size: false
# │           by_class: false
# │           disjoint: true
# │           cylindrical: true
# │       - transform: SampleSegments
# │         params:
# │           ratio: 0.2
# │           by_size: true
# │           by_class: false
# │       - transform: NAGRestrictSize
# │         params:
# │           level: 1+
# │           num_nodes: 50000
# │       - transform: NAGJitterKey
# │         params:
# │           key: pos
# │           sigma: 0.05
# │           trunc: 0.2
# │       - transform: RandomTiltAndRotate
# │         params:
# │           phi: 0.1
# │           theta: 180
# │       - transform: RandomAnisotropicScale
# │         params:
# │           delta: 0.2
# │       - transform: RandomAxisFlip
# │         params:
# │           p: 0.5
# │       - transform: OnTheFlyHorizontalEdgeFeatures
# │         params:
# │           keys:
# │           - mean_off
# │           - std_off
# │           - mean_dist
# │           use_mean_normal: false
# │       - transform: OnTheFlyVerticalEdgeFeatures
# │         params:
# │           keys: []
# │           use_mean_normal: false
# │       - transform: SampleEdges
# │         params:
# │           level: 1+
# │           n_min: -1
# │           n_max: -1
# │       - transform: NAGRestrictSize
# │         params:
# │           level: 1+
# │           num_edges: 1000000
# │       - transform: NAGJitterKey
# │         params:
# │           key:
# │           - verticality
# │           - planarity
# │           - elevation
# │           - scattering
# │           - linearity
# │           sigma: 0
# │           trunc: 0
# │       - transform: NAGJitterKey
# │         params:
# │           key: edge_attr
# │           sigma: 0
# │           trunc: 0
# │       - transform: NAGJitterKey
# │         params:
# │           key: v_edge_attr
# │           sigma: 0
# │           trunc: 0
# │       - transform: NAGDropoutColumns
# │         params:
# │           p: 0
# │           key:
# │           - verticality
# │           - planarity
# │           - elevation
# │           - scattering
# │           - linearity
# │           inplace: true
# │           to_mean: false
# │       - transform: NAGDropoutColumns
# │         params:
# │           p: 0.3
# │           key: edge_attr
# │           inplace: true
# │           to_mean: false
# │       - transform: NAGDropoutColumns
# │         params:
# │           p: 0
# │           key: v_edge_attr
# │           inplace: true
# │           to_mean: false
# │       - transform: NAGDropoutRows
# │         params:
# │           p: 0
# │           key:
# │           - verticality
# │           - planarity
# │           - elevation
# │           - scattering
# │           - linearity
# │           to_mean: false
# │       - transform: NAGDropoutRows
# │         params:
# │           p: 0
# │           key: edge_attr
# │           to_mean: false
# │       - transform: NAGDropoutRows
# │         params:
# │           p: 0
# │           key: v_edge_attr
# │           to_mean: false
# │       - transform: NAGJitterKey
# │         params:
# │           key: rgb
# │           sigma: 0.0
# │           trunc: 0.0
# │       - transform: NAGColorAutoContrast
# │         params:
# │           p: 0.0
# │       - transform: NAGColorDrop
# │         params:
# │           p: 0.0
# │       - transform: NAGAddSelfLoops
# │       - transform: OnTheFlyInstanceGraph
# │         params:
# │           level: -1
# │           num_classes: 2
# │           k_max: 30
# │           radius: 0.1
# │           adjacency_mode: radius-atomic
# │       - transform: QuantizePointCoordinates
# │         params:
# │           size: -1
# │       on_device_val_transform:
# │       - transform: NAGCast
# │       - transform: NodeSize
# │         params:
# │           low: 0
# │       - transform: OnTheFlyHorizontalEdgeFeatures
# │         params:
# │           keys:
# │           - mean_off
# │           - std_off
# │           - mean_dist
# │           use_mean_normal: false
# │       - transform: OnTheFlyVerticalEdgeFeatures
# │         params:
# │           keys: []
# │           use_mean_normal: false
# │       - transform: NAGAddSelfLoops
# │       - transform: OnTheFlyInstanceGraph
# │         params:
# │           level: -1
# │           num_classes: 2
# │           k_max: 30
# │           radius: 0.1
# │           adjacency_mode: radius-atomic
# │       - transform: QuantizePointCoordinates
# │         params:
# │           size: -1
# │       on_device_test_transform:
# │       - transform: NAGCast
# │       - transform: NodeSize
# │         params:
# │           low: 0
# │       - transform: OnTheFlyHorizontalEdgeFeatures
# │         params:
# │           keys:
# │           - mean_off
# │           - std_off
# │           - mean_dist
# │           use_mean_normal: false
# │       - transform: OnTheFlyVerticalEdgeFeatures
# │         params:
# │           keys: []
# │           use_mean_normal: false
# │       - transform: NAGAddSelfLoops
# │       - transform: OnTheFlyInstanceGraph
# │         params:
# │           level: -1
# │           num_classes: 2
# │           k_max: 30
# │           radius: 0.1
# │           adjacency_mode: radius-atomic
# │       - transform: QuantizePointCoordinates
# │         params:
# │           size: -1
# │       trainval: false
# │       val_on_test: false
# │       xy_tiling: 2
# │       voxel: 0.2
# │       knn: 25
# │       knn_r: 10
# │       knn_step: -1
# │       knn_min_search: 10
# │       ground_model: ransac
# │       ground_threshold: 5
# │       ground_xy_grid: 1
# │       ground_scale: 20
# │       pcp_regularization:
# │       - 0.1
# │       - 0.2
# │       - 0.3
# │       pcp_spatial_weight:
# │       - 0.1
# │       - 0.01
# │       - 0.001
# │       pcp_edge_reduce: mean
# │       pcp_cutoff:
# │       - 10
# │       - 30
# │       - 100
# │       pcp_k_adjacency: 10
# │       pcp_w_adjacency: 1
# │       pcp_iterations: 15
# │       graph_k_min: 1
# │       graph_k_max: 30
# │       graph_gap:
# │       - 5
# │       - 30
# │       - 30
# │       graph_se_ratio: 0.3
# │       graph_se_min: 50
# │       graph_cycles: 3
# │       graph_margin: 0.5
# │       graph_chunk:
# │       - 1000000.0
# │       - 100000.0
# │       - 100000.0
# │       sample_segment_ratio: 0.2
# │       sample_segment_by_size: true
# │       sample_segment_by_class: false
# │       sample_point_min: 32
# │       sample_point_max: 128
# │       sample_graph_r: 50
# │       sample_graph_k: 2
# │       sample_graph_max_nodes: 10000
# │       sample_graph_disjoint: true
# │       sample_graph_cylindrical: true
# │       sample_edge_n_min: -1
# │       sample_edge_n_max: -1
# │       pos_jitter: 0.05
# │       tilt_n_rotate_phi: 0.1
# │       tilt_n_rotate_theta: 180
# │       anisotropic_scaling: 0.2
# ...
# │     │                                                    │      │   K │      │
# │ 117 │ net.up_stages.0.in_mlp.mlp.4                       │ Gra… │ 192 │ tra… │
# │ 118 │ net.up_stages.0.transformer_blocks                 │ Mod… │ 23… │ tra… │
# │     │                                                    │      │   K │      │
# │ 119 │ net.up_stages.0.transformer_blocks.0               │ Tra… │ 23… │ tra… │
# │     │                                                    │      │   K │      │
# │ 120 │ net.up_stages.0.transformer_blocks.0.sa_norm       │ Gra… │ 192 │ tra… │
# │ 121 │ net.up_stages.0.transformer_blocks.0.sa            │ Sel… │ 23… │ tra… │
# │     │                                                    │      │   K │      │
# │ 122 │ net.up_stages.0.transformer_blocks.0.sa.qkv        │ Lin… │ 12… │ tra… │
# │     │                                                    │      │   K │      │
# │ 123 │ net.up_stages.0.transformer_blocks.0.sa.k_rpe      │ Lin… │ 2.1 │ tra… │
# │     │                                                    │      │   K │      │
# │ 124 │ net.up_stages.0.transformer_blocks.0.sa.q_rpe      │ Lin… │ 2.1 │ tra… │
# │     │                                                    │      │   K │      │
# │ 125 │ net.up_stages.0.transformer_blocks.0.sa.v_rpe      │ Lin… │ 2.1 │ tra… │
# │     │                                                    │      │   K │      │
# │ 126 │ net.up_stages.0.transformer_blocks.0.sa.out_proj   │ Lin… │ 4.2 │ tra… │
# │     │                                                    │      │   K │      │
# │ 127 │ net.up_stages.0.transformer_blocks.0.drop_path     │ Ide… │   0 │ tra… │
# │ 128 │ net.up_stages.0.pos_norm                           │ Uni… │   0 │ tra… │
# │ 129 │ net.up_stages.0.feature_fusion                     │ Cat… │   0 │ tra… │
# │ 130 │ net.up_stages.0.unpool                             │ Ind… │   0 │ tra… │
# │ 131 │ net.up_stages.0.fusion                             │ Cat… │   0 │ tra… │
# │ 132 │ head                                               │ Mod… │ 260 │ tra… │
# │ 133 │ head.0                                             │ Cla… │ 130 │ tra… │
# │ 134 │ head.0.classifier                                  │ Lin… │ 130 │ tra… │
# │ 135 │ head.1                                             │ Cla… │ 130 │ tra… │
# │ 136 │ head.1.classifier                                  │ Lin… │ 130 │ tra… │
# │ 137 │ train_cm                                           │ Con… │   0 │ tra… │
# │ 138 │ val_cm                                             │ Con… │   0 │ tra… │
# │ 139 │ test_cm                                            │ Con… │   0 │ tra… │
# │ 140 │ train_loss                                         │ Mea… │   0 │ tra… │
# │ 141 │ val_loss                                           │ Mea… │   0 │ tra… │
# │ 142 │ test_loss                                          │ Mea… │   0 │ tra… │
# │ 143 │ val_miou_best                                      │ Max… │   0 │ tra… │
# │ 144 │ val_oa_best                                        │ Max… │   0 │ tra… │
# │ 145 │ val_macc_best                                      │ Max… │   0 │ tra… │
# │ 146 │ val_n_p                                            │ Sum… │   0 │ tra… │
# │ 147 │ test_n_p                                           │ Sum… │   0 │ tra… │
# │ 148 │ val_n_sp                                           │ Sum… │   0 │ tra… │
# │ 149 │ test_n_sp                                          │ Sum… │   0 │ tra… │
# └─────┴────────────────────────────────────────────────────┴──────┴─────┴──────┘
# Trainable params: 211 K
# Non-trainable params: 0
# Total params: 211 K
# Total estimated model params size (MB): 0
# Modules in train mode: 150
# Modules in eval mode: 0
# /cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/torch/utils/
# data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker
# processes in total. Our suggested max number of worker in current system is 1,
# which is smaller than what this DataLoader is going to create. Please be aware
# that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/torch/utils/0:00:01 • 0:00:00 1.37it/s 0.00it/s
# data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker
# processes in total. Our suggested max number of worker in current system is 1,
# which is smaller than what this DataLoader is going to create. Please be aware
# that excessive worker creation might get DataLoader running slow or even freeze,
# lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/pytorch_ligh
# tning/loops/fit_loop.py:298: The number of training batches (11) is smaller than
# the logging interval Trainer(log_every_n_steps=50). Set a lower value for
# log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━ 0/11 0:00:00 • -:--:-- 0.00it/s v_num: 0.000
#                                                               val/loss: 51.842
#                                                               val/miou: 28.878
#                                                               val/oa: 45.052
#                                                               val/macc: 47.221
#                                                               val/iou_ground:
#                                                               32.622
#                                                               val/iou_not_groun…
#                                                               25.135
#                                                               val/miou_best:
#                                                               28.878
#                                                               val/oa_best:
#                                                               45.052
#                                                               val/macc_best:
# Epoch 0/0  ━╸━━━━━━━━━━━━━━━━ 1/11 0:00:04 • -:--:-- 0.00it/s v_num: 0.000
#                                                               val/loss: 51.842
#                                                               val/miou: 28.878
#                                                               val/oa: 45.052
#                                                               val/macc: 47.221
#                                                               val/iou_ground:
#                                                               32.622
#                                                               val/iou_not_groun…
#                                                               25.135
#                                                               val/miou_best:
#                                                               28.878
#                                                               val/oa_best:
#                                                               45.052
#                                                               val/macc_best:
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━━━━ 11/11 0:00:08 • 0:00:00 2.72it/s v_num: 0.0007mv_num: 0.000m━━━━━━━━━━━━━━━━━━━━━ 1/11 0:00:04 • -:--:-- 0.00it/s v_num: 0.000`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0/0  ━━━━━━━━━━━━━━━━━ 11/11 0:00:08 • 0:00:00 2.72it/s v_num: 0.000
#                                                               train/loss: 54.900
# [2026-02-16 13:43:20,474][__main__][INFO] - Starting testing!
# [2026-02-16 13:43:20,475][__main__][WARNING] - Best ckpt not found! Using current weights for testing...
# /cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python src/train.py experiment=semantic/dales_11g datamodul ...
# [2026-02-16 13:43:20,479][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,480][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# [2026-02-16 13:43:20,489][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,490][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# [2026-02-16 13:43:20,492][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,493][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# [2026-02-16 13:43:20,496][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,497][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# [2026-02-16 13:43:20,504][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,505][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# [2026-02-16 13:43:20,508][src.datasets.base][INFO] - Dataset hash: "f4917d740d77e00176910633f54203f5"
# [2026-02-16 13:43:20,508][src.datasets.base][INFO] - Preprocessed data can be found at:
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/train/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/val/f4917d740d77e00176910633f54203f5
#  - /cluster/home/jakobep/datasets/norway_binary_testing/norwaybinaryals/processed/test/f4917d740d77e00176910633f54203f5
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓━━━━ 2/2 0:00:01 • 0:00:00 1.42it/s 0.00it/s
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      test/iou_ground      │     32.68012237548828     │
# │    test/iou_not_ground    │     25.47163963317871     │
# │         test/loss         │    51.009857177734375     │
# │         test/macc         │    47.508052825927734     │
# │         test/miou         │    29.075881958007812     │
# │          test/oa          │     45.27194595336914     │
# └───────────────────────────┴───────────────────────────┘
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 0:00:01 • 0:00:00 1.42it/s
# [2026-02-16 13:43:25,546][__main__][INFO] - Best ckpt path: None
# [2026-02-16 13:43:25,547][__main__][INFO] - Last ckpt path:
# [2026-02-16 13:43:25,551][src.utils.utils][INFO] - Closing loggers...
# [2026-02-16 13:43:25,552][src.utils.utils][INFO] - Output dir: /cluster/home/jakobep/superpoint_transformer_new/logs/train/runs/2026-02-16_13-43-01
# Error executing job with overrides: ['experiment=semantic/dales_11g', 'datamodule=semantic/norway_binary', 'paths.data_dir=/cluster/home/jakobep/datasets/norway_binary_testing', 'trainer.max_epochs=1', 'callbacks.model_checkpoint.save_last=True', 'callbacks.model_checkpoint.every_n_epochs=1', 'callbacks.model_checkpoint.monitor=null', 'logger=csv']
# Traceback (most recent call last):
#   File "src/train.py", line 153, in <module>
#     main()
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/utils.py", line 457, in _run_app
#     run_and_report(
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/utils.py", line 223, in run_and_report
#     raise ex
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/utils.py", line 458, in <lambda>
#     lambda: hydra.run(
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/_internal/hydra.py", line 132, in run
#     _ = ret.return_value
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/core/utils.py", line 260, in return_value
#     raise self._return_value
#   File "/cluster/home/jakobep/.conda/envs/sptez/lib/python3.8/site-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#   File "src/train.py", line 144, in main
#     metric_value = utils.get_metric_value(
#   File "/cluster/home/jakobep/superpoint_transformer_new/src/utils/utils.py", line 195, in get_metric_value
#     raise Exception(
# Exception: Metric value not found! <metric_name=val/miou>
# Make sure metric name logged in LightningModule is correct!
# Make sure `optimized_metric` name in `hparams_search` config is correct!

# %% [markdown]
# ## Evaluering på en tile

# %%
# Finn siste checkpoint
from pathlib import Path
import glob

logs_dir = Path("logs/train/runs")
runs = sorted(logs_dir.glob("*"), key=lambda x: x.name, reverse=True)

ckpt_path = None
for run in runs:
    ckpts = list(run.glob("checkpoints/*.ckpt"))
    if ckpts:
        ckpt_path = sorted(ckpts, key=lambda x: x.stat().st_mtime, reverse=True)[0]
        print(f"Fant checkpoint: {ckpt_path}")
        break

if ckpt_path is None:
    print("⚠️  Ingen checkpoint funnet!")
    print("Tips: Kjør trening med flere epochs eller uten limit_train_batches")
    print("\nSiste runs (uten checkpoint):")
    for run in runs[:5]:
        print(f"  - {run.name}: {list(run.iterdir())}")
# Out:
# Fant checkpoint: logs/train/runs/2026-02-16_13-23-59/checkpoints/last.ckpt

# %% [markdown]
# ## Visuals

# %%
# Visualiser treningsresultater fra CSV-loggene
import pandas as pd
from pathlib import Path

# Finn siste run med metrics - sjekk flere mulige stier
possible_paths = [
    Path("logs/train/runs"),
    Path("/cluster/home/jakobep/superpoint_transformer_new/logs/train/runs"),
]

metrics_file = None
for logs_dir in possible_paths:
    if logs_dir.exists():
        runs = sorted(logs_dir.glob("*/csv/version_0/metrics.csv"), key=lambda x: x.parent.parent.parent.name, reverse=True)
        if runs:
            metrics_file = runs[0]
            break

if metrics_file and metrics_file.exists():
    print(f"Leser metrics fra: {metrics_file.parent.parent.parent.name}")
    
    df = pd.read_csv(metrics_file)
    
    # Vis siste resultater
    print("\n" + "="*50)
    print("RESULTATER")
    print("="*50)
    
    # Validation metrics
    val_cols = [c for c in df.columns if c.startswith('val/')]
    if val_cols:
        print("\n📊 Validation:")
        for col in val_cols:
            vals = df[col].dropna()
            if not vals.empty:
                val = vals.iloc[-1]
                print(f"  {col.replace('val/', '')}: {val:.2f}")
    
    # Test metrics
    test_cols = [c for c in df.columns if c.startswith('test/')]
    if test_cols:
        print("\n🧪 Test:")
        for col in test_cols:
            vals = df[col].dropna()
            if not vals.empty:
                val = vals.iloc[-1]
                print(f"  {col.replace('test/', '')}: {val:.2f}")
    
    # Train metrics
    train_cols = [c for c in df.columns if c.startswith('train/')]
    if train_cols:
        print("\n🏋️ Train:")
        for col in train_cols:
            vals = df[col].dropna()
            if not vals.empty:
                val = vals.iloc[-1]
                print(f"  {col.replace('train/', '')}: {val:.2f}")
else:
    print("⚠️ Ingen metrics funnet!")
    print("Tips: Sjekk at du har kjørt trening og at logs/train/runs/ inneholder resultater")
# Out:
# Leser metrics fra: 2026-02-16_13-43-01
#
# ==================================================
# RESULTATER
# ==================================================
#
# 🧪 Test:
#   iou_ground: 32.68
#   iou_not_ground: 25.47
#   loss: 51.01
#   macc: 47.51
#   miou: 29.08
#   oa: 45.27
#
# 🏋️ Train:
#   iou_ground: 38.63
#   iou_not_ground: 26.95
#   loss: 54.90
#   macc: 50.73
#   miou: 32.79
#   oa: 49.96

# %%
# Last modell og kjør prediksjon på en tile
import torch
from src.utils import init_config
from src.datasets.norway_binary import read_norway_laz
from src.datasets.norway_binary_config import CLASS_NAMES, CLASS_COLORS
import hydra

# Stier
CKPT_PATH = "/cluster/home/jakobep/superpoint_transformer_new/logs/train/runs/2026-02-02_14-20-56/checkpoints/last.ckpt"
DATA_ROOT = "/cluster/home/jakobep/datasets/norway_binary_testing"
TILE_PATH = f"{DATA_ROOT}/norwaybinaryals/raw/test/32-1-468-145-52.laz"

# Last konfig
cfg = init_config(
    overrides=[
        "experiment=semantic/dales_11g",
        "datamodule=semantic/norway_binary",
        f"paths.data_dir={DATA_ROOT}",
    ]
)

# Instantier datamodule og modell
datamodule = hydra.utils.instantiate(cfg.datamodule)
model = hydra.utils.instantiate(cfg.model)

# Last checkpoint
print(f"Laster checkpoint: {CKPT_PATH}")
ckpt = torch.load(CKPT_PATH, map_location='cuda')
model.load_state_dict(ckpt['state_dict'])
model = model.cuda().eval()
print("Modell lastet!")
# Out:
# Laster checkpoint: /cluster/home/larshfle/superpoint_transformer_new/logs/train/runs/2026-02-02-14_20-56/checkpoints/last.ckpt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 28
#      26 # Last checkpoint
#      27 print(f"Laster checkpoint: {CKPT_PATH}")
# ---> 28 ckpt = torch.load(CKPT_PATH, map_location='cuda')
#      29 model.load_state_dict(ckpt['state_dict'])
#      30 model = model.cuda().eval()
#
# File ~/.conda/envs/spt/lib/python3.8/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File ~/.conda/envs/spt/lib/python3.8/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File ~/.conda/envs/spt/lib/python3.8/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cluster/home/larshfle/superpoint_transformer_new/logs/train/runs/2026-02-02-14_20-56/checkpoints/last.ckpt'

# %%
# Les tile og kjør prediksjon
print(f"Leser tile: {TILE_PATH}")
data = read_norway_laz(TILE_PATH)
print(f"Antall punkter: {data.pos.shape[0]}")

# Preprocessing
nag = datamodule.pre_transform(data)
nag = nag.cuda()
nag = datamodule.on_device_val_transform(nag)

# Prediksjon
with torch.no_grad():
    output = model(nag)

# Legg til prediksjoner i NAG-objektet for visualisering
nag.semantic_pred = output.semantic_pred
print("Prediksjon ferdig!")

# %%
# Visualiser med innebygd show() - viser Labels, Predictions og Error mode
from src.visualization import show

# Legg til prediksjonene på NAG-en slik at "Semantic" modus fungerer
# Bruk voxel_semantic_pred med super_index for å mappe predictions til superpoints
nag[0].semantic_pred = output.voxel_semantic_pred(super_index=nag[0].super_index)

print(f"NAG har {nag.num_levels} nivåer")
print(f"Level 0: {nag[0].num_points} superpoints")
print(f"semantic_pred shape: {nag[0].semantic_pred.shape}")
print(f"Unike predictions: {nag[0].semantic_pred.unique().tolist()}")
print(f"Labels (y) unike: {nag[0].y.unique().tolist()}")

# Vis NAG med alle moduser (Labels, Semantic Pred, Error, osv.)
nag.show(
    class_names=CLASS_NAMES,
    class_colors=CLASS_COLORS,
    num_classes=2,
    radius=100,
    max_points=50000,
    centroids=True,
    h_edge=True,
    title="Norway Binary - Predictions vs Ground Truth"
)

# %%
# Eksporter visualisering som HTML-fil (kan åpnes i nettleser)
nag.show(
    class_names=CLASS_NAMES,
    class_colors=CLASS_COLORS,
    num_classes=2,
    radius=100,
    max_points=50000,
    path="norway_binary_visualization.html",  # lagrer som HTML
    title="Norway Binary Model Results"
)
print("Visualisering lagret til: norway_binary_visualization.html")
